# %%
import pandas as pd
import tensorflow
from tensorflow import keras
from keras.models import model_from_json                       # Importar as bibliotecas para uso
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
base = pd.read_csv('wine.csv')                   # Base de dados usada

entradas = base[base.columns[1:]].to_numpy()     # Entrada -  São 13 atributos
saidas = base[base.columns[0]]                   # Saida

valoresSaida = np.empty((177, 1), dtype=int)    # Vetor vazio para ser os valores de saida com 177 linhas e 1 coluna do tipo inteiro

for i in range(177):
   valoresSaida[i]= saidas[i]-1

entradasTrain, entradasTest, valoresSaidaTrain, valoresSaidaTest = train_test_split(entradas, valoresSaida, test_size=0.3) # separar a base de dados entre base de treino e base de teste

# %%
print("Quantidade de Dados de Treino:" ,len(entradasTrain))
print("Quantidade de Dados de Teste:" ,len(entradasTest))

print("Quantidade de Dados de Treino e dos atributos:" ,entradasTrain.shape)
print("Quantidade de Dados de Teste e dos atributos" ,entradasTest.shape)

print("Quantidade de Saidas de Treino e coluna:" ,valoresSaidaTrain.shape)
print("Quantidade de Saidas de Teste e coluna:" ,valoresSaidaTest.shape)

print("min: ", valoresSaidaTrain.min())  # Tá classificando o valor mínimo como 0
                                         # e o máximo 2
print("max: ", valoresSaidaTrain.max())
# Out:
# Quantidade de Dados de Treino: 123
# Quantidade de Dados de Teste: 54
# Quantidade de Dados de Treino e dos atributos: (123, 13)
# Quantidade de Dados de Teste e dos atributos (54, 13)
# Quantidade de Saidas de Treino e coluna: (123, 1)
# Quantidade de Saidas de Teste e coluna: (54, 1)
# min:  0
# max:  2

# %%
modelo = keras.Sequential([keras.layers.Dropout(0.2),                                 # Desevolvendo o modelo
                           keras.layers.Dense(130, activation=tensorflow.nn.relu),
                           keras.layers.Dense(70, activation=tensorflow.nn.relu),     # Usando Deep Learning com valores aleatórios para aumentar acurácia
                           keras.layers.Dense(40, activation=tensorflow.nn.relu),     # Usando  a função "relu"
                           keras.layers.Dense(13, activation=tensorflow.nn.relu),
                           keras.layers.Dense(3, activation=tensorflow.nn.softmax)    # Para a saída são tres possíveis valores 0,1 e 2 usando a função softmax
                           ])

modelo.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')   # Compilação do modelo

# %%
hist=modelo.fit(entradasTrain, valoresSaidaTrain, epochs=70, validation_split=0.3)  # Treinamento da rede com entradas de treino, valores de saída, época e a validação de split
# Out:
# Epoch 1/70
# 3/3 [==============================] - 2s 143ms/step - loss: 17.2512 - accuracy: 0.4186 - val_loss: 21.0668 - val_accuracy: 0.2432
# Epoch 2/70
# 3/3 [==============================] - 0s 22ms/step - loss: 14.9965 - accuracy: 0.3837 - val_loss: 10.8162 - val_accuracy: 0.5135
# Epoch 3/70
# 3/3 [==============================] - 0s 24ms/step - loss: 17.7017 - accuracy: 0.3837 - val_loss: 8.7272 - val_accuracy: 0.5135
# Epoch 4/70
# 3/3 [==============================] - 0s 32ms/step - loss: 6.8664 - accuracy: 0.4419 - val_loss: 7.4115 - val_accuracy: 0.2703
# Epoch 5/70
# 3/3 [==============================] - 0s 30ms/step - loss: 7.8009 - accuracy: 0.4535 - val_loss: 2.8364 - val_accuracy: 0.4324
# Epoch 6/70
# 3/3 [==============================] - 0s 25ms/step - loss: 4.6091 - accuracy: 0.3953 - val_loss: 5.9830 - val_accuracy: 0.2432
# Epoch 7/70
# 3/3 [==============================] - 0s 21ms/step - loss: 6.2173 - accuracy: 0.3837 - val_loss: 1.9166 - val_accuracy: 0.6486
# Epoch 8/70
# 3/3 [==============================] - 0s 22ms/step - loss: 5.9138 - accuracy: 0.5116 - val_loss: 3.0557 - val_accuracy: 0.5405
# Epoch 9/70
# 3/3 [==============================] - 0s 23ms/step - loss: 4.6050 - accuracy: 0.5581 - val_loss: 2.6896 - val_accuracy: 0.3784
# Epoch 10/70
# 3/3 [==============================] - 0s 31ms/step - loss: 4.1838 - accuracy: 0.3140 - val_loss: 2.2787 - val_accuracy: 0.3243
# Epoch 11/70
# 3/3 [==============================] - 0s 25ms/step - loss: 3.2703 - accuracy: 0.5116 - val_loss: 2.1144 - val_accuracy: 0.6486
# Epoch 12/70
# 3/3 [==============================] - 0s 23ms/step - loss: 4.4972 - accuracy: 0.5581 - val_loss: 3.2343 - val_accuracy: 0.5676
# Epoch 13/70
# 3/3 [==============================] - 0s 31ms/step - loss: 3.2177 - accuracy: 0.4535 - val_loss: 0.7380 - val_accuracy: 0.5676
# Epoch 14/70
# 3/3 [==============================] - 0s 30ms/step - loss: 2.6673 - accuracy: 0.5581 - val_loss: 2.3535 - val_accuracy: 0.4324
# Epoch 15/70
# 3/3 [==============================] - 0s 23ms/step - loss: 2.7401 - accuracy: 0.4884 - val_loss: 1.6712 - val_accuracy: 0.4865
# Epoch 16/70
# 3/3 [==============================] - 0s 34ms/step - loss: 1.8635 - accuracy: 0.5465 - val_loss: 1.1317 - val_accuracy: 0.5676
# Epoch 17/70
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2249 - accuracy: 0.5349 - val_loss: 0.7977 - val_accuracy: 0.4595
# Epoch 18/70
# 3/3 [==============================] - 0s 33ms/step - loss: 1.4724 - accuracy: 0.5465 - val_loss: 1.0267 - val_accuracy: 0.3243
# Epoch 19/70
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0992 - accuracy: 0.5930 - val_loss: 0.9088 - val_accuracy: 0.6486
# Epoch 20/70
# 3/3 [==============================] - 0s 26ms/step - loss: 1.5267 - accuracy: 0.5116 - val_loss: 0.9109 - val_accuracy: 0.5946
# Epoch 21/70
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2039 - accuracy: 0.5349 - val_loss: 1.1078 - val_accuracy: 0.3243
# Epoch 22/70
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8501 - accuracy: 0.5349 - val_loss: 0.7898 - val_accuracy: 0.7297
# Epoch 23/70
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3544 - accuracy: 0.6047 - val_loss: 0.5596 - val_accuracy: 0.6757
# Epoch 24/70
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8558 - accuracy: 0.6047 - val_loss: 0.9753 - val_accuracy: 0.3514
# Epoch 25/70
# 3/3 [==============================] - 0s 34ms/step - loss: 0.8208 - accuracy: 0.6163 - val_loss: 0.8037 - val_accuracy: 0.7297
# Epoch 26/70
# 3/3 [==============================] - 0s 23ms/step - loss: 1.5124 - accuracy: 0.5930 - val_loss: 0.7666 - val_accuracy: 0.5946
# Epoch 27/70
# 3/3 [==============================] - 0s 24ms/step - loss: 1.6559 - accuracy: 0.5000 - val_loss: 1.3068 - val_accuracy: 0.4595
# Epoch 28/70
# 3/3 [==============================] - 0s 30ms/step - loss: 1.4888 - accuracy: 0.5581 - val_loss: 0.8740 - val_accuracy: 0.5946
# Epoch 29/70
# 3/3 [==============================] - 0s 32ms/step - loss: 1.8624 - accuracy: 0.4767 - val_loss: 0.7880 - val_accuracy: 0.4865
# Epoch 30/70
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3931 - accuracy: 0.5465 - val_loss: 0.5842 - val_accuracy: 0.7027
# Epoch 31/70
# 3/3 [==============================] - 0s 39ms/step - loss: 0.9129 - accuracy: 0.6512 - val_loss: 0.8363 - val_accuracy: 0.7027
# Epoch 32/70
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2316 - accuracy: 0.5465 - val_loss: 0.8254 - val_accuracy: 0.6486
# Epoch 33/70
# 3/3 [==============================] - 0s 37ms/step - loss: 1.5935 - accuracy: 0.5233 - val_loss: 0.7489 - val_accuracy: 0.7027
# Epoch 34/70
# 3/3 [==============================] - 0s 36ms/step - loss: 1.2082 - accuracy: 0.5233 - val_loss: 1.1017 - val_accuracy: 0.4324
# Epoch 35/70
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1897 - accuracy: 0.5814 - val_loss: 0.5418 - val_accuracy: 0.7027
# Epoch 36/70
# 3/3 [==============================] - 0s 31ms/step - loss: 0.8752 - accuracy: 0.6047 - val_loss: 0.5569 - val_accuracy: 0.8378
# Epoch 37/70
# 3/3 [==============================] - 0s 38ms/step - loss: 1.1686 - accuracy: 0.5698 - val_loss: 0.7048 - val_accuracy: 0.7838
# Epoch 38/70
# 3/3 [==============================] - 0s 37ms/step - loss: 1.1668 - accuracy: 0.5698 - val_loss: 0.7981 - val_accuracy: 0.8108
# Epoch 39/70
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3403 - accuracy: 0.5581 - val_loss: 0.6662 - val_accuracy: 0.6486
# Epoch 40/70
# 3/3 [==============================] - 0s 38ms/step - loss: 0.9351 - accuracy: 0.5814 - val_loss: 0.6905 - val_accuracy: 0.7027
# Epoch 41/70
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0732 - accuracy: 0.5698 - val_loss: 0.7977 - val_accuracy: 0.7838
# Epoch 42/70
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0834 - accuracy: 0.5581 - val_loss: 1.2096 - val_accuracy: 0.5676
# Epoch 43/70
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4914 - accuracy: 0.5814 - val_loss: 0.8901 - val_accuracy: 0.7297
# Epoch 44/70
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8132 - accuracy: 0.6279 - val_loss: 1.1867 - val_accuracy: 0.5676
# Epoch 45/70
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3334 - accuracy: 0.5581 - val_loss: 0.6366 - val_accuracy: 0.7027
# Epoch 46/70
# 3/3 [==============================] - 0s 27ms/step - loss: 0.8458 - accuracy: 0.5930 - val_loss: 0.6787 - val_accuracy: 0.7027
# Epoch 47/70
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9509 - accuracy: 0.6279 - val_loss: 0.5587 - val_accuracy: 0.7838
# Epoch 48/70
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7890 - accuracy: 0.6163 - val_loss: 0.5370 - val_accuracy: 0.7027
# Epoch 49/70
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0932 - accuracy: 0.5698 - val_loss: 0.5744 - val_accuracy: 0.7027
# Epoch 50/70
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8657 - accuracy: 0.6395 - val_loss: 0.5263 - val_accuracy: 0.7027
# Epoch 51/70
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7884 - accuracy: 0.6744 - val_loss: 0.6520 - val_accuracy: 0.8378
# Epoch 52/70
# 3/3 [==============================] - 0s 33ms/step - loss: 0.9875 - accuracy: 0.5581 - val_loss: 0.8924 - val_accuracy: 0.8108
# Epoch 53/70
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9248 - accuracy: 0.6860 - val_loss: 1.5103 - val_accuracy: 0.5135
# Epoch 54/70
# 3/3 [==============================] - 0s 36ms/step - loss: 1.8315 - accuracy: 0.6047 - val_loss: 1.5496 - val_accuracy: 0.4324
# Epoch 55/70
# 3/3 [==============================] - 0s 32ms/step - loss: 1.6429 - accuracy: 0.5000 - val_loss: 1.8513 - val_accuracy: 0.5135
# Epoch 56/70
# 3/3 [==============================] - 0s 46ms/step - loss: 1.5634 - accuracy: 0.5116 - val_loss: 1.6542 - val_accuracy: 0.5946
# Epoch 57/70
# 3/3 [==============================] - 0s 28ms/step - loss: 1.7214 - accuracy: 0.5116 - val_loss: 2.0180 - val_accuracy: 0.4595
# Epoch 58/70
# 3/3 [==============================] - 0s 36ms/step - loss: 1.6116 - accuracy: 0.5000 - val_loss: 1.4917 - val_accuracy: 0.6216
# Epoch 59/70
# 3/3 [==============================] - 0s 27ms/step - loss: 1.7339 - accuracy: 0.5814 - val_loss: 0.5469 - val_accuracy: 0.8649
# Epoch 60/70
# 3/3 [==============================] - 0s 36ms/step - loss: 1.4092 - accuracy: 0.6047 - val_loss: 0.6450 - val_accuracy: 0.7027
# Epoch 61/70
# 3/3 [==============================] - 0s 33ms/step - loss: 1.7572 - accuracy: 0.5814 - val_loss: 0.5826 - val_accuracy: 0.7027
# Epoch 62/70
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0294 - accuracy: 0.6395 - val_loss: 1.0613 - val_accuracy: 0.4865
# Epoch 63/70
# 3/3 [==============================] - 0s 39ms/step - loss: 1.1886 - accuracy: 0.6628 - val_loss: 0.8653 - val_accuracy: 0.7027
# Epoch 64/70
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0256 - accuracy: 0.6744 - val_loss: 1.6074 - val_accuracy: 0.5676
# Epoch 65/70
# 3/3 [==============================] - 0s 28ms/step - loss: 1.5432 - accuracy: 0.5349 - val_loss: 0.9233 - val_accuracy: 0.5405
# Epoch 66/70
# 3/3 [==============================] - 0s 19ms/step - loss: 0.9359 - accuracy: 0.5814 - val_loss: 0.6770 - val_accuracy: 0.7027
# Epoch 67/70
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0144 - accuracy: 0.6395 - val_loss: 0.7435 - val_accuracy: 0.5946
# Epoch 68/70
# 3/3 [==============================] - 0s 21ms/step - loss: 0.8788 - accuracy: 0.6395 - val_loss: 0.5108 - val_accuracy: 0.8919
# Epoch 69/70
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9337 - accuracy: 0.6977 - val_loss: 0.7729 - val_accuracy: 0.7027
# Epoch 70/70
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7036 - accuracy: 0.7093 - val_loss: 0.8732 - val_accuracy: 0.5405

# %%
plt.plot(hist.history['accuracy'])            # Acurácia - precisão de uma tabela ou de uma operação ou proximidade entre o valor obtido experimentalmente e o valor verdadeiro na medição de uma grandeza física.
plt.plot(hist.history['val_accuracy'])
plt.title('Acurácia por épocas')              # Gráfico da acurácia por épocas
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.legend(['Treino', 'Validação'])

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss por épocas')               # Gráfico das perdas por épocas
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend(['Treino', 'Validação'])

# %%
model_json = modelo.to_json()
with open("model.json", "w") as json_file:
   json_file.write(model_json)                      # Salvamento do modelo

modelo.save_weights("model.h5")
print("Modelo Salvo")
# Out:
# Modelo Salvo

# %%
json_file = open("model.json", "r")
loaded_model_json = json_file.read()
json_file.close()

loaded_model = model_from_json(loaded_model_json)     # Carregamento do modelo acima
loaded_model.load_weights("model.h5")
print("Modelo Carregado")
# Out:
# Modelo Carregado

# %%
loaded_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
perda_teste, acuracia_teste = loaded_model.evaluate(entradasTest, valoresSaidaTest)   # Carregamento das entradas de teste e valores de testes
print("Perda do teste: ", perda_teste)                                                # print da perde de teste
print("Acurácia do teste: ", acuracia_teste)                                          # print da acurácia de teste
testes=loaded_model.predict(entradasTest)                                             # variável para carregar todas saídas das entradas
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8576 - accuracy: 0.5926
# Perda do teste:  0.8575897216796875
# Acurácia do teste:  0.5925925970077515
# 2/2 [==============================] - 0s 10ms/step

# %%
x=0
for i in testes:
   print(np.argmax(i), valoresSaidaTest[x])
   x=x+1
# Out:
# 2 [2]
# 2 [0]
# 2 [2]
# 0 [0]
# 0 [0]
# 2 [2]
# 2 [2]
# 2 [1]
# 2 [2]
# 0 [0]
# 2 [2]
# 0 [0]
# 0 [0]
# 0 [0]
# 2 [1]
# 2 [0]
# 2 [0]
# 2 [1]
# 2 [2]
# 2 [2]
# 2 [1]
# 2 [2]
# 2 [2]
# 0 [0]
# 2 [2]
# 2 [2]
# 2 [1]
# 2 [1]
# 2 [1]
# 2 [1]
# 2 [1]
# 2 [2]
# 1 [1]
# 0 [0]
# 2 [2]
# 2 [1]
# 0 [0]
# 0 [0]
# 2 [1]
# 2 [1]
# 2 [1]
# 1 [1]
# 2 [2]
# 2 [2]
# 0 [0]
# 2 [1]
# 2 [2]
# 2 [1]
# 2 [1]
# 2 [0]
# 2 [1]
# 1 [1]
# 0 [0]
# 2 [0]
